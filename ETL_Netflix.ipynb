# %%
# Importing necessary libraries for the project
import numpy as np 
import pandas as pd
import warnings

# Suppress all warnings
warnings.filterwarnings("ignore")

# %%
# Extracting data from CSV
Netflix_mv = pd.read_csv('./Input/netflix_movies.csv')
Netflix_mv.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
# Extracting Data through Kaggle API
import os
import zipfile
import pandas as pd
# !pip install kaggle

# Set up Kaggle API key
os.environ['KAGGLE_CONFIG_DIR'] = "C:/Users/sathi/kaggle"

# Use Kaggle API to download the dataset
# !kaggle datasets download -d ankulsharma150/netflix-data-analysis

# Unzip the downloaded file
with zipfile.ZipFile('netflix-data-analysis.zip', 'r') as zip_ref:
    zip_ref.extractall('netflix_data')

# Load the CSV file into a Pandas DataFrame
df = pd.read_csv('netflix_data/netflix_movies (1).csv')

# Display the first few rows
df.head()
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/ankulsharma150/netflix-data-analysis
# License(s): other
# netflix-data-analysis.zip: Skipping, found more recently modified local copy (use --force to force download)
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# ...

# %%
Netflix_mv.tail(5)
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
Netflix_mv.shape
# Out:
# (8807, 12)

# %%
Netflix_mv.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
Netflix_mv.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
Netflix_mv.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
Netflix_mv.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
Netflix_mv.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
# Handling missing values
# Fill missing values in 'director', 'cast', and 'country' with 'Unknown'
Netflix_mv['director'].fillna('Unknown', inplace=True)
Netflix_mv['cast'].fillna('Unknown', inplace=True)
Netflix_mv['country'].fillna('Unknown', inplace=True)
Netflix_mv
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          Unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          Unknown
# 4         s5  TV Show           Kota Factory          Unknown
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb          Unknown
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               Unknown  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
# Display the number of missing values
missing_values = Netflix_mv.isnull().sum()
missing_values
# Out:
# show_id          0
# type             0
# title            0
# director         0
# cast             0
# country          0
# date_added      10
# release_year     0
# rating           4
# duration         3
# listed_in        0
# description      0
# dtype: int64

# %%
# Drop the 'date_added' column from the DataFrame
# Netflix_mv.drop(columns=['date_added'], inplace=True)
# Netflix_mv
# Drop rows with null values in specific columns (e.g., 'date_added' and 'director')
Netflix_mv_cleaned = Netflix_mv.dropna(subset=['date_added', 'rating', 'duration'])
Netflix_mv_cleaned.shape
# Out:
# (8790, 12)

# %%
Netflix_mv_cleaned.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
Netflix_mv_cleaned.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water          Unknown
#
#                                                 cast        country  \
# 0                                            Unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
Netflix_mv_cleaned.rename(columns={"show_id":"ID", "date_added":"date_arrival"}, inplace=True )
Netflix_mv_cleaned.head(2)
# Out:
#    ID     type                 title         director  \
# 0  s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1  s2  TV Show         Blood & Water          Unknown
#
#                                                 cast        country  \
# 0                                            Unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#          date_arrival  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
Netflix_mv_cleaned.columns = Netflix_mv_cleaned.columns.str.lower()
Netflix_mv_cleaned.head(2)
# Out:
#    id     type                 title         director  \
# 0  s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1  s2  TV Show         Blood & Water          Unknown
#
#                                                 cast        country  \
# 0                                            Unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#          date_arrival  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
Netflix_mv_cleaned.columns = Netflix_mv_cleaned.columns.str.upper()
Netflix_mv_cleaned.head(2)
# Out:
#    ID     TYPE                 TITLE         DIRECTOR  \
# 0  s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1  s2  TV Show         Blood & Water          Unknown
#
#                                                 CAST        COUNTRY  \
# 0                                            Unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#          DATE_ARRIVAL  RELEASE_YEAR RATING   DURATION  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          LISTED_IN  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          DESCRIPTION
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
# Subsetting columns:

Netflix_mv_cleaned[["TITLE", "DIRECTOR"]].head(5)
# Out:
#                    TITLE         DIRECTOR
# 0   Dick Johnson Is Dead  Kirsten Johnson
# 1          Blood & Water          Unknown
# 2              Ganglands  Julien Leclercq
# 3  Jailbirds New Orleans          Unknown
# 4           Kota Factory          Unknown

# %%
Netflix_mv_cleaned['DIRECTOR'].info
# Out:
# <bound method Series.info of 0       Kirsten Johnson
# 1               Unknown
# 2       Julien Leclercq
# 3               Unknown
# 4               Unknown
#              ...
# 8802      David Fincher
# 8803            Unknown
# 8804    Ruben Fleischer
# 8805       Peter Hewitt
# 8806        Mozez Singh
# Name: DIRECTOR, Length: 8790, dtype: object>

# %%
Netflix_mv_cleaned['DIRECTOR'].value_counts(ascending=False)
# Out:
# DIRECTOR
# Unknown                           2621
# Rajiv Chilaka                       19
# Raúl Campos, Jan Suter              18
# Suhas Kadav                         16
# Marcus Raboy                        16
#                                   ...
# Raymie Muzquiz, Stu Livingston       1
# Joe Menendez                         1
# Eric Bross                           1
# Will Eisenberg                       1
# Mozez Singh                          1
# Name: count, Length: 4527, dtype: int64

# %%
Netflix_mv_cleaned['DIRECTOR'].unique()
# Out:
# array(['Kirsten Johnson', 'Unknown', 'Julien Leclercq', ...,
#        'Majid Al Ansari', 'Peter Hewitt', 'Mozez Singh'], dtype=object)

# %%
len(Netflix_mv_cleaned['DIRECTOR'].unique())
# Out:
# 4527

# %%
# Extracting data from CSV
# mv = pd.read_csv('./cars.csv', delimiter=';')
# mv.head()
# # Extracting data from CSV
# data = pd.read_csv('./cars.csv', delimiter=';')
# data.head()
# # Remove the row that contains data types by checking the Car column does not contain 'STRING'
# data_cleaned = data[data['Car'] != 'STRING']

# # Display the cleaned data
# data_cleaned.head()

# %%
Netflix_mv_cleaned.head(2)
# Out:
#    ID     TYPE                 TITLE         DIRECTOR  \
# 0  s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1  s2  TV Show         Blood & Water          Unknown
#
#                                                 CAST        COUNTRY  \
# 0                                            Unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#          DATE_ARRIVAL  RELEASE_YEAR RATING   DURATION  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          LISTED_IN  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          DESCRIPTION
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %% [markdown]
# ### Perform aggregations, filtering, and other transformations*

# %%
# Count the number of shows by type (Movie/TV Show)
shows_count = Netflix_mv_cleaned['TYPE'].value_counts().reset_index()
shows_count.columns = ['TYPE', 'COUNT']
shows_count
# Out:
#       TYPE  COUNT
# 0    Movie   6126
# 1  TV Show   2664

# %%
# Ensure 'DURATION' column is treated as string for replacing ' min', creating new column
Netflix_mv_cleaned['DURATION'] = Netflix_mv_cleaned['DURATION'].astype(str)

# Strip 'min' from movie durations, ignore errors for non-movie entries
Netflix_mv_cleaned['DURATION_MOVIE'] = pd.to_numeric(Netflix_mv_cleaned['DURATION'].str.replace(' min', '', regex=False), errors='coerce')

# # Filter only the rows where TYPE is 'Movie'
movies_only = Netflix_mv_cleaned[Netflix_mv_cleaned['TYPE'] == 'Movie']

# # Calculate the average duration of movies
average_duration = movies_only['DURATION_MOVIE'].mean()

# # Print the result
print(f'Average Duration of Movies: {average_duration:.2f} minutes')
# Out:
# Average Duration of Movies: 99.58 minutes

# %%
Netflix_mv_cleaned.isnull().sum()
# Out:
# ID                   0
# TYPE                 0
# TITLE                0
# DIRECTOR             0
# CAST                 0
# COUNTRY              0
# DATE_ARRIVAL         0
# RELEASE_YEAR         0
# RATING               0
# DURATION             0
# LISTED_IN            0
# DESCRIPTION          0
# DURATION_MOVIE    2664
# dtype: int64

# %%
Netflix_mv_cleaned.head(3)
# Out:
#    ID     TYPE                 TITLE         DIRECTOR  \
# 0  s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1  s2  TV Show         Blood & Water          Unknown
# 2  s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 CAST        COUNTRY  \
# 0                                            Unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
#
#          DATE_ARRIVAL  RELEASE_YEAR RATING   DURATION  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
#
#                                            LISTED_IN  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
# ...

# %%
Netflix_mv_cleaned.dtypes
# Out:
# ID                 object
# TYPE               object
# TITLE              object
# DIRECTOR           object
# CAST               object
# COUNTRY            object
# DATE_ARRIVAL       object
# RELEASE_YEAR        int64
# RATING             object
# DURATION           object
# LISTED_IN          object
# DESCRIPTION        object
# DURATION_MOVIE    float64
# dtype: object

# %%
Netflix_mv_cleaned['DURATION_MOVIE'].fillna('Unknown', inplace=True)
Netflix_mv_cleaned.head(2)
# Out:
#    ID     TYPE                 TITLE         DIRECTOR  \
# 0  s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1  s2  TV Show         Blood & Water          Unknown
#
#                                                 CAST        COUNTRY  \
# 0                                            Unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#          DATE_ARRIVAL  RELEASE_YEAR RATING   DURATION  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          LISTED_IN  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          DESCRIPTION DURATION_MOVIE
# 0  As her father nears the end of his life, filmm...           90.0
# 1  After crossing paths at a party, a Cape Town t...        Unknown

# %%
Netflix_mv_cleaned.isnull().sum()
# Out:
# ID                0
# TYPE              0
# TITLE             0
# DIRECTOR          0
# CAST              0
# COUNTRY           0
# DATE_ARRIVAL      0
# RELEASE_YEAR      0
# RATING            0
# DURATION          0
# LISTED_IN         0
# DESCRIPTION       0
# DURATION_MOVIE    0
# dtype: int64

# %%
df = Netflix_mv_cleaned.query('RELEASE_YEAR == 2021')
# Display the filtered DataFrame
df.head(5)
# Out:
#    ID     TYPE                  TITLE         DIRECTOR  \
# 1  s2  TV Show          Blood & Water          Unknown
# 2  s3  TV Show              Ganglands  Julien Leclercq
# 3  s4  TV Show  Jailbirds New Orleans          Unknown
# 4  s5  TV Show           Kota Factory          Unknown
# 5  s6  TV Show          Midnight Mass    Mike Flanagan
#
#                                                 CAST       COUNTRY  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...       Unknown
# 3                                            Unknown       Unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...         India
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...       Unknown
#
#          DATE_ARRIVAL  RELEASE_YEAR RATING   DURATION  \
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# ...

# %%
df1 = Netflix_mv_cleaned.query('RELEASE_YEAR == 2021 and TYPE == "Movie"')
# Netflix_mv_cleaned.filter(col('RELEASE_YEAR')=2021) and 
# Display the filtered DataFrame
df1.head(5)
# Out:
#      ID   TYPE                             TITLE  \
# 6    s7  Movie  My Little Pony: A New Generation
# 9   s10  Movie                      The Starling
# 12  s13  Movie                      Je Suis Karl
# 13  s14  Movie  Confessions of an Invisible Girl
# 18  s19  Movie                         Intrusion
#
#                          DIRECTOR  \
# 6   Robert Cullen, José Luis Ucha
# 9                  Theodore Melfi
# 12            Christian Schwochow
# 13                  Bruno Garotti
# 18                     Adam Salky
#
#                                                  CAST  \
# 6   Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 13  Klara Castanho, Lucca Picon, Júlia Gomes, Marc...
# 18  Freida Pinto, Logan Marshall-Green, Robert Joh...
#
#                     COUNTRY        DATE_ARRIVAL  RELEASE_YEAR RATING DURATION  \
# ...

# %%
Netflix_mv_cleaned.head(5)
# Out:
#    ID     TYPE                  TITLE         DIRECTOR  \
# 0  s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1  s2  TV Show          Blood & Water          Unknown
# 2  s3  TV Show              Ganglands  Julien Leclercq
# 3  s4  TV Show  Jailbirds New Orleans          Unknown
# 4  s5  TV Show           Kota Factory          Unknown
#
#                                                 CAST        COUNTRY  \
# 0                                            Unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# 3                                            Unknown        Unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#          DATE_ARRIVAL  RELEASE_YEAR RATING   DURATION  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# ...

# %%
# Netflix_mv_cleaned["TITLE_DIRECTOR"] = Netflix_mv_cleaned["TITLE"] + ", " + Netflix_mv_cleaned["DIRECTOR"]

# # Step 2: Create a new DataFrame containing only the TITLE_DIRECTOR column
# df = Netflix_mv_cleaned[["TITLE_DIRECTOR"]]

# # Display the new DataFrame
# df.head(2)

# Step 1: Create the TITLE_DIRECTOR column in the original DataFrame
Netflix_mv_cleaned["TITLE_DIRECTOR"] = Netflix_mv_cleaned["TITLE"] + ", " + Netflix_mv_cleaned["DIRECTOR"]

Netflix_mv_cleaned.tail(5)
# Out:
#          ID     TYPE        TITLE         DIRECTOR  \
# 8802  s8803    Movie       Zodiac    David Fincher
# 8803  s8804  TV Show  Zombie Dumb          Unknown
# 8804  s8805    Movie   Zombieland  Ruben Fleischer
# 8805  s8806    Movie         Zoom     Peter Hewitt
# 8806  s8807    Movie       Zubaan      Mozez Singh
#
#                                                    CAST        COUNTRY  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                            Unknown        Unknown
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#            DATE_ARRIVAL  RELEASE_YEAR RATING   DURATION  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
Netflix_mv_cleaned.dtypes
# Out:
# ID                object
# TYPE              object
# TITLE             object
# DIRECTOR          object
# CAST              object
# COUNTRY           object
# DATE_ARRIVAL      object
# RELEASE_YEAR       int64
# RATING            object
# DURATION          object
# LISTED_IN         object
# DESCRIPTION       object
# DURATION_MOVIE    object
# TITLE_DIRECTOR    object
# dtype: object

# %% [markdown]
# ## Changing Data Type

# %%
# Netflix_mv_cleaned = pd.DataFrame(Netflix_mv_cleaned)

# # Step 1: Clean the DATE_ARRIVAL column by stripping whitespace
# Netflix_mv_cleaned['DATE_ARRIVAL'] = Netflix_mv_cleaned['DATE_ARRIVAL'].str.strip()

# # Step 2: Convert the DATE_ARRIVAL column to datetime (with time set to 00:00:00)
# Netflix_mv_cleaned['DATE_ARRIVAL'] = pd.to_datetime(Netflix_mv_cleaned['DATE_ARRIVAL'], errors='coerce')

# # Step 3: Optionally, you can check the data types of the DataFrame
# print(Netflix_mv_cleaned.dtypes)

# %%
# Step 1: Clean the DATE_ARRIVAL column by stripping whitespace
Netflix_mv_cleaned['DATE_ARRIVAL'] = Netflix_mv_cleaned['DATE_ARRIVAL'].str.strip()

# Step 2: Convert the DATE_ARRIVAL column to datetime (with time set to 00:00:00)
Netflix_mv_cleaned['DATE_ARRIVAL'] = pd.to_datetime(Netflix_mv_cleaned['DATE_ARRIVAL'], errors='coerce')

# Step 3: Check for any NaT values
if Netflix_mv_cleaned['DATE_ARRIVAL'].isnull().any():
    print("Warning: There are NaT values in DATE_ARRIVAL after conversion.")

# Step 4: Optionally, check the data types of the DataFrame
print(Netflix_mv_cleaned.dtypes)
# Out:
# ID                        object
# TYPE                      object
# TITLE                     object
# DIRECTOR                  object
# CAST                      object
# COUNTRY                   object
# DATE_ARRIVAL      datetime64[ns]
# RELEASE_YEAR               int64
# RATING                    object
# DURATION                  object
# LISTED_IN                 object
# DESCRIPTION               object
# DURATION_MOVIE            object
# TITLE_DIRECTOR            object
# dtype: object

# %%
Netflix_mv_cleaned.head(5)
# Out:
#    ID     TYPE                  TITLE         DIRECTOR  \
# 0  s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1  s2  TV Show          Blood & Water          Unknown
# 2  s3  TV Show              Ganglands  Julien Leclercq
# 3  s4  TV Show  Jailbirds New Orleans          Unknown
# 4  s5  TV Show           Kota Factory          Unknown
#
#                                                 CAST        COUNTRY  \
# 0                                            Unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# 3                                            Unknown        Unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   DATE_ARRIVAL  RELEASE_YEAR RATING   DURATION  \
# 0   2021-09-25          2020  PG-13     90 min
# 1   2021-09-24          2021  TV-MA  2 Seasons
# 2   2021-09-24          2021  TV-MA   1 Season
# ...

# %%
# Load Data to local folder
# Save the transformed data to CSV
Netflix_mv_cleaned.to_csv('Netflix_transformed_data.csv', index=False)

# %%
# !pip install google-cloud-storage

# export GOOGLE_APPLICATION_CREDENTIALS=".\ETL\gcpprofessionaldataengineer-f37028d44b80.json"

# from google.cloud import storage

# def upload_to_gcs(bucket_name, source_file_name, destination_blob_name):
#     """Uploads a file to the GCS bucket."""
    
#     # Initialize a storage client
#     storage_client = storage.Client()

#     # Get the bucket
#     bucket = storage_client.bucket(bucket_name)

#     # Create a new blob and upload the file
#     blob = bucket.blob(destination_blob_name)
#     blob.upload_from_filename(source_file_name)

#     print(f"File {source_file_name} uploaded to {destination_blob_name} in bucket {bucket_name}.")

# # Define parameters
# bucket_name = 'etl-netflixdata-analysis'  # Replace with your bucket name
# source_file_name = 'Netflix_transformed_data.csv'  # Local file to upload
# destination_blob_name = 'Netflix_transformed_data.csv'  # GCS path (can include folder structure)

# # Call the function to upload the file
# upload_to_gcs(bucket_name, source_file_name, destination_blob_name)

# %%
# !pip install google-cloud-storage
import os
from google.cloud import storage

# Set the path to your service account key
service_account_key_path = r'D:\Miraclesoft\ETL\gcpprofessionaldataengineer-f37028d44b80.json'

# Set the environment variable for the Google Cloud credentials
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = service_account_key_path

# Function to upload a file to GCS
def upload_to_gcs(bucket_name, source_file_name, destination_blob_name):
    # Initialize a Google Cloud Storage client
    storage_client = storage.Client()

    # Get the bucket object
    bucket = storage_client.bucket(bucket_name)

    # Get a blob object (GCS's equivalent of a file object)
    blob = bucket.blob(destination_blob_name)

    # Upload the file to GCS
    blob.upload_from_filename(source_file_name)

    print(f"File {source_file_name} uploaded to {destination_blob_name} in bucket {bucket_name}.")

# Replace with your own GCS bucket and file paths
bucket_name = 'etl-netflixdata-analysis'  # Replace with your bucket name
source_file_name = 'Netflix_transformed_data.csv'  # The file you want to upload
destination_blob_name = 'Netflix_transformed_data.csv'  # The name it will have in GCS

# Upload the file to GCS
upload_to_gcs(bucket_name, source_file_name, destination_blob_name)
# Out:
# ...
# File Netflix_transformed_data.csv uploaded to Netflix_transformed_data.csv in bucket etl-netflixdata-analysis.

# %%
Netflix_mv_cleaned.shape
# Out:
# (8790, 14)
